# %%
import pandas as pd
df = pd.read_csv('dataset_Facebook.csv', sep=';')

# %%
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
df.sample(10)
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 303            124940  Photo         3           6             5          3
# 279            126345  Photo         1           6             2          3
# 377            111620  Photo         3           4             2         13
# 256            129600  Photo         1           7             4          6
# 96             137059  Photo         1          10             6          3
# 328            120050  Photo         3           5             4         12
# 57             138329  Photo         1          11             5          3
# 481             86491   Link         1           1             4          4
# 391            109670  Photo         2           4             1         13
# 337            119198  Photo         3           5             6          6
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# ...

# %%
df.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
df.tail()
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 495             85093  Photo         3           1             7          2
# 496             81370  Photo         2           1             5          8
# 497             81370  Photo         1           1             5          2
# 498             81370  Photo         3           1             4         11
# 499             81370  Photo         2           1             4          4
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 495   0.0                       4684                             7536
# 496   0.0                       3480                             6229
# 497   0.0                       3778                             7216
# 498   0.0                       4156                             7564
# 499   NaN                       4188                             7292
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
#Creating subset

df_subset = df.loc[0:7, ['Page total likes','Type','Category','Post Month']]
print(df_subset)
# Out:
#    Page total likes    Type  Category  Post Month
# 0            139441   Photo         2          12
# 1            139441  Status         2          12
# 2            139441   Photo         3          12
# 3            139441   Photo         2          12
# 4            139441   Photo         2          12
# 5            139441  Status         2          12
# 6            139441   Photo         3          12
# 7            139441   Photo         3          12

# %%
#  subset 2

df_subset2 = df.loc[0:5, ['Category','Post Month','Post Weekday','Post Hour']]
print(df_subset2)
# Out:
#    Category  Post Month  Post Weekday  Post Hour
# 0         2          12             4          3
# 1         2          12             3         10
# 2         3          12             3          3
# 3         2          12             2         10
# 4         2          12             2          3
# 5         2          12             1          9

# %%
df.shape
# Out:
# (500, 19)

# %%
df_subset3 = df.iloc[0:7,[4,5,11]]
print(df_subset3)
# Out:
#    Post Weekday  Post Hour  Lifetime Post Consumptions
# 0             4          3                         159
# 1             3         10                        1674
# 2             3          3                         154
# 3             2         10                        1119
# 4             2          3                         580
# 5             1          9                        1389
# 6             1          3                         364

# %%
df_subset4 = df.iloc[[0,1,2,3,4],[4,5,11]]
print(df_subset4)
# Out:
#    Post Weekday  Post Hour  Lifetime Post Consumptions
# 0             4          3                         159
# 1             3         10                        1674
# 2             3          3                         154
# 3             2         10                        1119
# 4             2          3                         580

# %%
df.iloc[[0,1,2,3,4],[4,5,11]]
# Out:
#    Post Weekday  Post Hour  Lifetime Post Consumptions
# 0             4          3                         159
# 1             3         10                        1674
# 2             3          3                         154
# 3             2         10                        1119
# 4             2          3                         580

# %%
df_merged=pd.concat([df_subset2, df_subset3], axis=1 , join = 'inner')
print(df_merged)
# Out:
#    Category  Post Month  Post Weekday  Post Hour  Post Weekday  Post Hour  \
# 0         2          12             4          3             4          3
# 1         2          12             3         10             3         10
# 2         3          12             3          3             3          3
# 3         2          12             2         10             2         10
# 4         2          12             2          3             2          3
# 5         2          12             1          9             1          9
#
#    Lifetime Post Consumptions
# 0                         159
# 1                        1674
# 2                         154
# 3                        1119
# 4                         580
# 5                        1389

# %%
dfmerge= pd.merge(df_subset3,df_subset2)
dfmerge
# Out:
#    Post Weekday  Post Hour  Lifetime Post Consumptions  Category  Post Month
# 0             4          3                         159         2          12
# 1             3         10                        1674         2          12
# 2             3          3                         154         3          12
# 3             2         10                        1119         2          12
# 4             2          3                         580         2          12
# 5             1          9                        1389         2          12

# %%
# Merging the two dataframes using concat() function

df_merged=pd.concat([df_subset2, df_subset3], axis=1, join='inner')
print(df_merged)
# Out:
#    Category  Post Month  Post Weekday  Post Hour  Post Weekday  Post Hour  \
# 0         2          12             4          3             4          3
# 1         2          12             3         10             3         10
# 2         3          12             3          3             3          3
# 3         2          12             2         10             2         10
# 4         2          12             2          3             2          3
# 5         2          12             1          9             1          9
#
#    Lifetime Post Consumptions
# 0                         159
# 1                        1674
# 2                         154
# 3                        1119
# 4                         580
# 5                        1389

# %%
import numpy as np

# %%
df.sort_values(by=['Category'])
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 128            136393  Photo         1          10             6         13
# 144            136013  Photo         1          10             2          3
# 145            136013  Photo         1          10             1         10
# 402            107907  Photo         1           4             3          4
# 401            107907  Photo         1           4             3         13
# ..                ...    ...       ...         ...           ...        ...
# 356            116435  Photo         3           5             1         13
# 359            116091  Photo         3           5             7          2
# 361            116091  Photo         3           5             6          3
# 143            136013  Photo         3          10             2         10
# 162            135617  Photo         3           9             6         10
#
# ...

# %%
a = df.T
print(a)
# Out:
#                                                        0       1       2    \
# Page total likes                                    139441  139441  139441
# Type                                                 Photo  Status   Photo
# Category                                                 2       2       3
# Post Month                                              12      12      12
# Post Weekday                                             4       3       3
# Post Hour                                                3      10       3
# Paid                                                   0.0     0.0     0.0
# Lifetime Post Total Reach                             2752   10460    2413
# Lifetime Post Total Impressions                       5091   19057    4373
# Lifetime Engaged Users                                 178    1457     177
# Lifetime Post Consumers                                109    1361     113
# ...

# %%
df_transposed = df.transpose()
print(df_transposed)
# Out:
#                                                        0       1       2    \
# Page total likes                                    139441  139441  139441
# Type                                                 Photo  Status   Photo
# Category                                                 2       2       3
# Post Month                                              12      12      12
# Post Weekday                                             4       3       3
# Post Hour                                                3      10       3
# Paid                                                   0.0     0.0     0.0
# Lifetime Post Total Reach                             2752   10460    2413
# Lifetime Post Total Impressions                       5091   19057    4373
# Lifetime Engaged Users                                 178    1457     177
# Lifetime Post Consumers                                109    1361     113
# ...

# %%
df.shape
# Out:
# (500, 19)

# %%
df_reshape=df.pivot(columns='Type', values='like') 
print('\n-------------------------- df_reshape --------------------------\n')
print(df_reshape)
# Out:
# -------------------------- df_reshape --------------------------
#
# Type  Link   Photo  Status  Video
# 0      NaN    79.0     NaN    NaN
# 1      NaN     NaN   130.0    NaN
# 2      NaN    66.0     NaN    NaN
# 3      NaN  1572.0     NaN    NaN
# 4      NaN   325.0     NaN    NaN
# ..     ...     ...     ...    ...
# 495    NaN    53.0     NaN    NaN
# 496    NaN    53.0     NaN    NaN
# 497    NaN    93.0     NaN    NaN
# 498    NaN    91.0     NaN    NaN
# 499    NaN    91.0     NaN    NaN
#
# [500 rows x 4 columns]
