# %%
import pandas as pd
import numpy as np

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('AirQuality.csv',sep=';')
df1 = pd.read_csv('Heart.csv.csv')

# %%
df1.sample(5)
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 276         277   66    0    nonanginal     146   278    0        2    152
# 272         273   46    1  asymptomatic     140   311    0        0    120
# 43           44   59    1    nonanginal     150   212    1        0    157
# 301         302   57    0    nontypical     130   236    0        2    174
# 89           90   51    0    nonanginal     130   256    0        2    149
#
#      ExAng  Oldpeak  Slope   Ca        Thal  AHD
# 276      0      0.0      2  1.0      normal   No
# 272      1      1.8      2  2.0  reversable  Yes
# 43       0      1.6      1  0.0      normal   No
# 301      0      0.0      2  1.0      normal  Yes
# 89       0      0.5      1  0.0      normal   No

# %%
plt.hist(df1["Age"], bins=10, edgecolor = 'black')
plt.show()

# %%
plt.figure(figsize = (15,11))
sns.heatmap(df1.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.scatter(df1['Age'],df1['Chol'], alpha=0.5)

# %%
# Bar chart

# %%
Sex_counts = df1['Sex'].value_counts()
plt.bar(Sex_counts.index, Sex_counts.values)
# Out:
# <BarContainer object of 2 artists>

# %%
sns.distplot(df1['Age'])
plt.show()
# Out:
# C:\Users\trupt\AppData\Local\Temp\ipykernel_12784\3453043443.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1['Age'])

# %%
plt.scatter(df['NOx(GT)'], df['NO2(GT)'], alpha=0.5)

# %%
plt.scatter(df['PT08.S1(CO)'], df['PT08.S2(NMHC)'], alpha=0.5)
